# %% [markdown]
# # Boston:

# %%
import warnings
warnings.filterwarnings(action='ignore',category=FutureWarning)
warnings.filterwarnings(action='ignore',category=DeprecationWarning)

# %%
import pandas as pd
a=pd.read_csv('/content/Boston.csv')
a.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
a = a.drop(columns='Unnamed: 0')

# %%
a.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
print('shape : ',a.shape)
a.info()
# Out:
# shape :  (506, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
a.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
a.isnull().any()
# Out:
# crim       False
# zn         False
# indus      False
# chas       False
# nox        False
# rm         False
# age        False
# dis        False
# rad        False
# tax        False
# ptratio    False
# black      False
# lstat      False
# medv       False
# dtype: bool

# %%
from sklearn.decomposition import PCA

# %%
pc=PCA(n_components=10)

# %%
pc
# Out:
# PCA(n_components=10)

# %%
model=pc.fit(a)

# %%
#model=pc.fit_transform(a)

# %%
model.explained_variance_ratio_
# Out:
# array([8.04572190e-01, 1.62705572e-01, 2.14083271e-02, 6.95759438e-03,
#        2.00539401e-03, 1.21514667e-03, 4.44138834e-04, 3.52919538e-04,
#        2.31912833e-04, 7.08317644e-05])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(model.explained_variance_ratio_)
# Out:
# <ipython-input-16-eca4283e2a3a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(model.explained_variance_ratio_)
# <Axes: ylabel='Density'>

# %%
plt.hist(model.explained_variance_ratio_)
# Out:
# (array([8., 0., 1., 0., 0., 0., 0., 0., 0., 1.]),
#  array([7.08317644e-05, 8.05209676e-02, 1.60971103e-01, 2.41421239e-01,
#         3.21871375e-01, 4.02321511e-01, 4.82771647e-01, 5.63221783e-01,
#         6.43671919e-01, 7.24122054e-01, 8.04572190e-01]),
#  <BarContainer object of 10 artists>)

# %%
a.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
categorical_var=a.drop(['crim', 'zn', 'indus',  'nox', 'rm', 'age', 'dis',  'tax',
       'ptratio', 'black', 'lstat'],axis=1)
continuous_var=a.drop([ 'chas', 'rad'],axis=1)

# %%
for i in categorical_var:
    if i != 'medv':
        sns.catplot(x=i,data=categorical_var,kind='count')
        sns.catplot(x=i,y='medv',data=categorical_var,kind='box')

# %%
import matplotlib.pyplot as plt
for i in continuous_var:
    if i != 'medv':

        sns.distplot(continuous_var[i])
        plt.show()
# Out:
# <ipython-input-21-d490eff8d919>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# <ipython-input-21-d490eff8d919>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# <ipython-input-21-d490eff8d919>:5: UserWarning:
#
# ...

# %%
for i in continuous_var:
    if i != 'medv':
        sns.scatterplot(x=i,y='medv',data=continuous_var)

        plt.show()

# %%
#linear regression:

# %%
#corelation:
a_cor=a.corr()
a_cor
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(a_cor,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

from sklearn.pipeline import make_pipeline

# %%
x=a.drop(['medv'],axis=1)
y=a['medv']

# %%
x_s=StandardScaler()

# %%
x1=x_s.fit_transform(x)
x1=pd.DataFrame(x1)
x1.columns=x.columns

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y,test_size=0.2,random_state=12)

# %%
lm=cross_val_score(LinearRegression(),x_train,y_train,cv=5)
rr=cross_val_score(Ridge(),x_train,y_train,cv=5)
lr=cross_val_score(Lasso(),x_train,y_train,cv=5)
gb=cross_val_score(GradientBoostingRegressor(),x_train,y_train,cv=5)
xgb=cross_val_score(XGBRegressor(),x_train,y_train,cv=5)

# %%
PFmodel = make_pipeline(PolynomialFeatures(), LinearRegression())
pr = cross_val_score(PFmodel, x_train, y_train, cv=5)

# %%
print("cross validation score:")
print("linear regression :",lm,lm.mean(),lm.std())
print("ridge regression :",rr,rr.mean(),rr.std())
print("lasso regression :",lr,lr.mean(),lr.std())
print("gradient boosting :",gb,gb.mean(),gb.std())
print("XG boost :",xgb,xgb.mean(),xgb.std())
print("polynomial regression :",pr,pr.mean(),pr.std())
# Out:
# cross validation score:
# linear regression : [0.70392942 0.57553959 0.78478802 0.74777365 0.6625577 ] 0.69491767684896 0.07245679848925465
# ridge regression : [0.70475827 0.57405256 0.7851434  0.74812017 0.66277125] 0.6949691286687808 0.07308868560147326
# lasso regression : [0.66856667 0.53434668 0.69268834 0.65538739 0.59787125] 0.6297720645189375 0.05699700090182252
# gradient boosting : [0.87601996 0.82339151 0.93817296 0.9340035  0.83912809] 0.882143202716396 0.0472617818370396
# XG boost : [0.88672251 0.7309579  0.90799442 0.93049646 0.74615647] 0.8404655515729538 0.08448851727636653
# polynomial regression : [0.87620368 0.50813009 0.89621943 0.8502796  0.81732094] 0.7896307497087279 0.14320870929352528

# %%
#Linear regression:
lrm =LinearRegression()

# %%
model=lrm.fit(x_train,y_train)
pred_test_lrm =model.predict(x_test)
print("coeff -",model.coef_)
print("intercept -",model.intercept_)
# Out:
# coeff - [-0.84772412  1.08908322  0.20806726  0.76532464 -2.09747006  2.62045816
#   0.41334594 -2.89789313  2.82171985 -2.2822341  -1.77372866  0.8295733
#  -4.00256638]
# intercept - 22.576701710437796

# %%
print("TEST DATA:")
print("\'accuracy\' - ",r2_score(y_pred=pred_test_lrm ,y_true=y_test)*100,"%")
print("\'error\' - ",mean_squared_error(y_pred=pred_test_lrm ,y_true=y_test))
# Out:
# TEST DATA:
# 'accuracy' -  74.8403167892452 %
# 'error' -  20.558051634230054

# %%
#ridge regression:
rrm =Ridge()

# %%
#grid search value:
param={"alpha":[10,1,0.1,0.01,0.001,0.0001,0.00001]}
grid=GridSearchCV(estimator=rrm,param_grid=param,cv=3,scoring='neg_mean_squared_error')
grid.fit(x_train,y_train)
print(grid.best_params_)
pd.DataFrame(grid.cv_results_)
# Out:
# {'alpha': 1e-05}
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0       0.003265      0.000383         0.001958        0.000341     10.00000
# 1       0.002920      0.000235         0.001601        0.000033      1.00000
# 2       0.002891      0.000111         0.001599        0.000019      0.10000
# 3       0.002790      0.000099         0.001569        0.000032      0.01000
# 4       0.002779      0.000187         0.001926        0.000284      0.00100
# 5       0.002948      0.000211         0.001585        0.000011      0.00010
# 6       0.002859      0.000116         0.001680        0.000131      0.00001
#
#               params  split0_test_score  split1_test_score  split2_test_score  \
# 0      {'alpha': 10}         -25.927856         -29.485351         -22.915824
# 1       {'alpha': 1}         -25.938309         -28.926857         -23.071709
# 2     {'alpha': 0.1}         -25.938803         -28.889300         -23.097407
# ...

# %%
rrm =Ridge(alpha=0.00001)
model=rrm .fit(x_train,y_train)
pred_test_rrm =model.predict(x_test)

# %%
print("TEST DATA:")
print("accuracy - ",r2_score(y_pred=pred_test_rrm,y_true=y_test)*100,"%")
print("error - ",mean_squared_error(y_pred=pred_test_rrm,y_true=y_test))
# Out:
# TEST DATA:
# accuracy -  74.8403170807713 %
# error -  20.558051396023203

# %%
#polynomial regression:
pf=PolynomialFeatures(degree=2)

# %%
model=pf.fit_transform(x_train)
model_test=pf.fit_transform(x_test)

# %%
model1=lrm.fit(model,y_train)
pred_test_pf =model1.predict(model_test)

# %%
print("TEST DATA:")
print("accuracy - ",r2_score(y_pred=pred_test_pf,y_true=y_test)*100,"%")
print("error - ",mean_squared_error(y_pred=pred_test_pf,y_true=y_test))
# Out:
# TEST DATA:
# accuracy -  81.07596453805695 %
# error -  15.462885398665339

# %%
#Gradient boosting:
gb=GradientBoostingRegressor()
gb
# Out:
# GradientBoostingRegressor()

# %%
param={'alpha':[0.9,0.1,0.01,0.001,0.0001,0.00001],'max_depth':[2,3,5,7,9,10,15,20]}
grid=GridSearchCV(estimator=gb,param_grid=param,cv=3,scoring='neg_mean_squared_error')
grid.fit(x_train,y_train)
print(grid.best_params_)
pd.DataFrame(grid.cv_results_)
# Out:
# {'alpha': 0.1, 'max_depth': 3}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0        0.127276      0.001812         0.002391        0.000071      0.90000
# 1        0.148597      0.000852         0.002494        0.000092      0.90000
# 2        0.207460      0.006326         0.003346        0.000997      0.90000
# 3        0.266769      0.003235         0.003026        0.000041      0.90000
# 4        0.317887      0.005909         0.003513        0.000043      0.90000
# 5        0.336699      0.004807         0.003762        0.000149      0.90000
# 6        0.380041      0.007441         0.003639        0.000013      0.90000
# 7        0.495907      0.033716         0.005347        0.000401      0.90000
# 8        0.160759      0.000324         0.003241        0.000173      0.10000
# 9        0.207723      0.007050         0.003793        0.000605      0.10000
# 10       0.227252      0.024680         0.003712        0.001518      0.10000
# ...

# %%
gb=GradientBoostingRegressor(alpha= 0.00001 ,max_depth=3)
model=gb.fit(x_train,y_train)
pred_test_gb =model.predict(x_test)

# %%
print("TEST DATA:")
print("accuracy - ",r2_score(y_pred=pred_test_gb,y_true=y_test)*100,"%")
print("error - ",mean_squared_error(y_pred=pred_test_gb,y_true=y_test))
# Out:
# TEST DATA:
# accuracy -  86.37653732672862 %
# error -  11.13177168122683

# %%
#xgboost:
xgb=XGBRegressor()
xgb
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
param={'base_score':[0.9,0.5,0.1,0.01,0.001,0.0001,0.00001],'max_depth':[2,3,5,7,9,10,15,20]}
grid=GridSearchCV(estimator=xgb,param_grid=param,cv=3,scoring='neg_mean_squared_error')
grid.fit(x_train,y_train)
print(grid.best_params_)
# Out:
# {'base_score': 0.9, 'max_depth': 5}

# %%
xgb=XGBRegressor(base_score=0.9,max_depth=5)

# %%
model=xgb.fit(x_train,y_train)
pred_test_xgb =model.predict(x_test)

# %%
print("TEST DATA:")
print("accuracy - ",r2_score(y_pred=pred_test_xgb,y_true=y_test)*100,"%")
print("error - ",mean_squared_error(y_pred=pred_test_xgb,y_true=y_test))
# Out:
# TEST DATA:
# accuracy -  86.21980128876372 %
# error -  11.259841161849304

# %%
print("\'Linear Regression Accuracy\' - ",r2_score(y_pred=pred_test_lrm ,y_true=y_test)*100,"%")
print("\'Ridge Regression Accuracy\' - ",r2_score(y_pred=pred_test_rrm,y_true=y_test)*100,"%")
print("\'Polynomial RegressionAccuracy\' - ",r2_score(y_pred=pred_test_pf,y_true=y_test)*100,"%")
print("\'Gradient Boosting Accuracy\' - ",r2_score(y_pred=pred_test_gb,y_true=y_test)*100,"%")
print("\'XG Boost Accuracy\' - ",r2_score(y_pred=pred_test_xgb,y_true=y_test)*100,"%")
# Out:
# 'Linear Regression Accuracy' -  74.8403167892452 %
# 'Ridge Regression Accuracy' -  74.8403170807713 %
# 'Polynomial RegressionAccuracy' -  81.07596453805695 %
# 'Gradient Boosting Accuracy' -  86.37653732672862 %
# 'XG Boost Accuracy' -  86.21980128876372 %

# %%
pd.DataFrame(pred_test_gb)
# Out:
#              0
# 0    23.099215
# 1    13.351176
# 2     6.299400
# 3    25.512529
# 4    29.342501
# ..         ...
# 97   15.383693
# 98   31.065815
# 99   14.560670
# 100  31.530498
# 101  19.516921
#
# [102 rows x 1 columns]
